# %%
#Importing Libraries
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input

# %%
count = 0
# Ganti 'Images/' dengan rute absolut direktori
base_path = r'C:\Users\PersonaL\COBA\Ekspresi'

# List semua subdirektori
dirs = os.listdir(base_path)

for dir in dirs:
    # Menggabungkan rute untuk subdirektori
    dir_path = os.path.join(base_path, dir)
    
    # Memastikan hanya direktori yang diproses
    if os.path.isdir(dir_path):
        files = os.listdir(dir_path)
        print(dir + ' Folder has ' + str(len(files)) + ' Images')
        count += len(files)

print('Images Folder has ' + str(count) + ' Images')
# Out:
# angry Folder has 3995 Images
# fearful Folder has 4097 Images
# happy Folder has 7215 Images
# neutral Folder has 4965 Images
# sad Folder has 4830 Images
# surprised Folder has 3171 Images
# Images Folder has 28273 Images

# %%
base_dir = r'C:\Users\PersonaL\COBA\Ekspresi'
train_ds = train_ds.batch(32)
val_ds = val_ds.batch(32)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'training',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'validation',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))
# Out:
# Found 28273 files belonging to 6 classes.
# Using 22619 files for training.
# Found 28273 files belonging to 6 classes.
# Using 5654 files for validation.

# %%
flower_names = train_ds.class_names
flower_names
# Out:
# ['angry', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Definisikan daftar nama ekspresi wajah
expression_names = ['surprised', 'sad', 'happy', 'angry', 'fearful']

i = 0
plt.figure(figsize=(10,10))

# Menampilkan 9 gambar pertama dari dataset pelatihan
for images, labels in train_ds.take(1):  # Ambil satu batch dari dataset pelatihan
    for i in range(9):  # Tampilkan 9 gambar pertama
        plt.subplot(3,3, i+1)  # Membuat grid 3x3
        plt.imshow(images[i].numpy().astype('uint8'))  # Menampilkan gambar
        plt.title(expression_names[labels[i]])  # Menampilkan nama ekspresi wajah
        plt.axis('off')  # Menghilangkan sumbu

# %%
# Perintah AUTOTUNE = tf.data.AUTOTUNE digunakan dalam TensorFlow untuk mengoptimalkan proses pemuatan dan pemrosesan data saat melatih model, terutama ketika menggunakan tf.data.Dataset.

AUTOTUNE = tf.data.AUTOTUNE

# %%
# Digunakan untuk mempersiapkan dan mengoptimalkan pemuatan serta pemopresan  data dalam tensor flow 
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %%
data_augmentation = Sequential([
    layers.RandomFlip("horizontal", input_shape = (img_size,img_size,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(5)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = Sequential([
#       2     data_augmentation,
#       3     layers.Rescaling(1./255),
#       4     Conv2D(16, 3, padding='same', activation='relu'),
#       5     MaxPooling2D(),
#       6     Conv2D(32, 3, padding='same', activation='relu'),
#       7     MaxPooling2D(),
#       8     Conv2D(64, 3, padding='same', activation='relu'),
#       9     MaxPooling2D(),
#      10     Dropout(0.2),
#      11     Flatten(),
#      12     Dense(128, activation='relu'),
#      13     Dense(5)
#      14 ])
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ...

# %%
history = model.fit(
        Ekspresi_train_ds,
    epochs=15,
    validation_data=Ekspresi_val_ds
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Menggunakan batch untuk dataset
# ----> 2 Ekspresi_train_ds = Ekspresi_train_ds.batch(32)  # Batching dataset untuk training
#       3 Ekspresi_val_ds = Ekspresi_val_ds.batch(32)      # Batching dataset untuk validation
#       5 # Jika perlu, prefetch untuk meningkatkan performa
#
# NameError: name 'Ekspresi_train_ds' is not defined

# %%
history = model.fit(Ekspresi, epochs=15, validation_data=Ekspresi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 history = model.fit(Ekspresi, epochs=15, validation_data=Ekspresi)
#
# NameError: name 'Ekspresi' is not defined
